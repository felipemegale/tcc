# %%
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in /home/felipe/anaconda3/envs/py37/lib/python3.7/site-packages (1.1.2)

# %%
import pandas as pd
import apyori

# %%
sample_2019 = pd.read_csv('/home/felipe/repos/tcc/nyc_data/csv/2019_preprocessed_sample.csv')
sample_2020 = pd.read_csv('/home/felipe/repos/tcc/nyc_data/csv/2020_preprocessed_sample.csv')
sample_2021 = pd.read_csv('/home/felipe/repos/tcc/nyc_data/csv/2021_preprocessed_sample.csv')

# %%
sample_2019 = sample_2019.drop(['dropoff_datetime', 'pickup_datetime', 'PROBABLE_CASE_COUNT', 'CASE_COUNT_7DAY_AVG', 'ALL_CASE_COUNT_7DAY_AVG'], axis=1)
sample_2020 = sample_2020.drop(['dropoff_datetime', 'pickup_datetime', 'PROBABLE_CASE_COUNT', 'CASE_COUNT_7DAY_AVG', 'ALL_CASE_COUNT_7DAY_AVG'], axis=1)
sample_2021 = sample_2021.drop(['dropoff_datetime', 'pickup_datetime', 'PROBABLE_CASE_COUNT', 'CASE_COUNT_7DAY_AVG', 'ALL_CASE_COUNT_7DAY_AVG'], axis=1)

# %%
def process_pu(x):
    return str(x)+' pickup'

def process_do(x):
    return str(x)+' dropoff'

def process_sr_flag(x):
    if x == 0:
        return 'not shared'
    return 'shared'

def process_pu_day(x):
    if x == 0:
        return 'dawn pickup'
    elif x == 1:
        return 'morning pickup'
    elif x == 2:
        return 'noon pickup'
    return 'night pickup'

def process_do_day(x):
    if x == 0:
        return 'dawn dropoff'
    elif x == 1:
        return 'morning dropoff'
    elif x == 2:
        return 'noon dropoff'
    return 'night dropoff'

def process_duration(x):
    duration_minutes = x/60
    
    if duration_minutes <= 15:
        return 'short trip'
    elif 15 < duration_minutes <= 30:
        return 'medium-short trip'
    elif 30 < duration_minutes <= 45:
        return 'medium-long trip'
    elif 45 < duration_minutes <= 60:
        return 'long trip'
    return 'longer trip'

def process_case(x):
    if x <= 500:
        return 'low count'
    elif 500 < x <= 1000:
        return 'mid-low count'
    elif 1000 < x <= 2000:
        return 'mid-high count'
    elif 2000 < x <= 3000:
        return 'high count'
    return 'higher count'

# %%
sample_2019['PULocationID'] = sample_2019['PULocationID'].apply(process_pu)
sample_2019['DOLocationID'] = sample_2019['DOLocationID'].apply(process_do)
sample_2019['SR_Flag'] = sample_2019['SR_Flag'].apply(process_sr_flag)
sample_2019['pickup_day_period'] = sample_2019['pickup_day_period'].apply(process_pu_day)
sample_2019['dropoff_day_period'] = sample_2019['dropoff_day_period'].apply(process_do_day)
sample_2019['trip_duration'] = sample_2019['trip_duration'].apply(process_duration)
sample_2019['CASE_COUNT'] = sample_2019['CASE_COUNT'].apply(process_case)

sample_2020['PULocationID'] = sample_2020['PULocationID'].apply(process_pu)
sample_2020['DOLocationID'] = sample_2020['DOLocationID'].apply(process_do)
sample_2020['SR_Flag'] = sample_2020['SR_Flag'].apply(process_sr_flag)
sample_2020['pickup_day_period'] = sample_2020['pickup_day_period'].apply(process_pu_day)
sample_2020['dropoff_day_period'] = sample_2020['dropoff_day_period'].apply(process_do_day)
sample_2020['trip_duration'] = sample_2020['trip_duration'].apply(process_duration)
sample_2020['CASE_COUNT'] = sample_2020['CASE_COUNT'].apply(process_case)

sample_2021['PULocationID'] = sample_2021['PULocationID'].apply(process_pu)
sample_2021['DOLocationID'] = sample_2021['DOLocationID'].apply(process_do)
sample_2021['SR_Flag'] = sample_2021['SR_Flag'].apply(process_sr_flag)
sample_2021['pickup_day_period'] = sample_2021['pickup_day_period'].apply(process_pu_day)
sample_2021['dropoff_day_period'] = sample_2021['dropoff_day_period'].apply(process_do_day)
sample_2021['trip_duration'] = sample_2021['trip_duration'].apply(process_duration)
sample_2021['CASE_COUNT'] = sample_2021['CASE_COUNT'].apply(process_case)

# %%
sample_2019_transactions = sample_2019.values.tolist()
sample_2020_transactions = sample_2020.values.tolist()
sample_2021_transactions = sample_2021.values.tolist()

# %%
rules_2019 = list(apyori.apriori(sample_2019_transactions, min_support=0.2, min_confidence=0.3))
rules_2020 = list(apyori.apriori(sample_2020_transactions, min_support=0.2, min_confidence=0.3))
rules_2021 = list(apyori.apriori(sample_2021_transactions, min_support=0.2, min_confidence=0.3))

# %%
for i in range(len(rules_2019)):
    LHS=list(rules_2019[i][2][0][0])
    RHS=list(rules_2019[i][2][0][1])
    support=rules_2019[i][1]
    confidence=rules_2019[i][2][0][2]
    lift=rules_2019[i][2][0][3]
    print("LHS:",LHS,"--","RHS:",RHS)
    print("Support:",support)
    print("Confidence:",confidence)
    print("Lift:",lift)
    print(10*"----")
# Out:
# LHS: [] -- RHS: ['low count']
# Support: 1.0
# Confidence: 1.0
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['medium-short trip']
# Support: 0.3602934102934103
# Confidence: 0.3602934102934103
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['night dropoff']
# Support: 0.3491622574955908
# Confidence: 0.3491622574955908
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['night pickup']
# Support: 0.3410373577040244
# Confidence: 0.3410373577040244
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared']
# Support: 0.820386403719737
# Confidence: 0.820386403719737
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['short trip']
# Support: 0.48890492223825555
# Confidence: 0.48890492223825555
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['low count', 'medium-short trip']
# Support: 0.3602934102934103
# Confidence: 0.3602934102934103
# Lift: 1.0
# ----------------------------------------
# LHS: ['morning dropoff'] -- RHS: ['low count']
# Support: 0.2350208433541767
# Confidence: 1.0
# Lift: 1.0
# ----------------------------------------
# LHS: ['morning pickup'] -- RHS: ['low count']
# Support: 0.2432780182780183
# Confidence: 1.0
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['low count', 'night dropoff']
# Support: 0.3491622574955908
# Confidence: 0.3491622574955908
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['night pickup', 'low count']
# Support: 0.3410373577040244
# Confidence: 0.3410373577040244
# Lift: 1.0
# ----------------------------------------
# LHS: ['noon dropoff'] -- RHS: ['low count']
# Support: 0.2804433221099888
# Confidence: 1.0
# Lift: 1.0
# ----------------------------------------
# LHS: ['noon pickup'] -- RHS: ['low count']
# Support: 0.28778659611992946
# Confidence: 1.0
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'low count']
# Support: 0.820386403719737
# Confidence: 0.820386403719737
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['short trip', 'low count']
# Support: 0.48890492223825555
# Confidence: 0.48890492223825555
# Lift: 1.0
# ----------------------------------------
# LHS: ['medium-short trip'] -- RHS: ['not shared']
# Support: 0.2853495270161937
# Confidence: 0.7919920788554392
# Lift: 0.9653890840516685
# ----------------------------------------
# LHS: ['morning dropoff'] -- RHS: ['morning pickup']
# Support: 0.22995430495430497
# Confidence: 0.9784421742022411
# Lift: 4.021909505543887
# ----------------------------------------
# LHS: ['morning pickup'] -- RHS: ['not shared']
# Support: 0.20344717011383678
# Confidence: 0.8362743644242334
# Lift: 1.0193664359044206
# ----------------------------------------
# LHS: [] -- RHS: ['night pickup', 'night dropoff']
# Support: 0.3285072951739618
# Confidence: 0.3285072951739618
# Lift: 1.0
# ----------------------------------------
# LHS: ['night dropoff'] -- RHS: ['not shared']
# Support: 0.2821789321789322
# Confidence: 0.8081598916300268
# Lift: 0.9850966422233796
# ----------------------------------------
# LHS: ['night pickup'] -- RHS: ['not shared']
# Support: 0.27534872534872534
# Confidence: 0.8073858160362943
# Lift: 0.9841530922203289
# ----------------------------------------
# LHS: ['noon dropoff'] -- RHS: ['noon pickup']
# Support: 0.26713163379830046
# Confidence: 0.9525334095619238
# Lift: 3.3098602311727334
# ----------------------------------------
# LHS: ['noon dropoff'] -- RHS: ['not shared']
# Support: 0.23207471540804875
# Confidence: 0.8275280497391553
# Lift: 1.008705222303828
# ----------------------------------------
# LHS: ['noon pickup'] -- RHS: ['not shared']
# Support: 0.23745791245791245
# Confidence: 0.8251180411437803
# Lift: 1.005767571723019
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'short trip']
# Support: 0.4215127465127465
# Confidence: 0.4215127465127465
# Lift: 1.0
# ----------------------------------------
# LHS: ['medium-short trip'] -- RHS: ['not shared', 'low count']
# Support: 0.2853495270161937
# Confidence: 0.7919920788554392
# Lift: 0.9653890840516685
# ----------------------------------------
# LHS: ['morning dropoff'] -- RHS: ['morning pickup', 'low count']
# Support: 0.22995430495430497
# Confidence: 0.9784421742022411
# Lift: 4.021909505543887
# ----------------------------------------
# LHS: ['morning pickup'] -- RHS: ['not shared', 'low count']
# Support: 0.20344717011383678
# Confidence: 0.8362743644242334
# Lift: 1.0193664359044206
# ----------------------------------------
# LHS: [] -- RHS: ['night pickup', 'low count', 'night dropoff']
# Support: 0.3285072951739618
# Confidence: 0.3285072951739618
# Lift: 1.0
# ----------------------------------------
# LHS: ['night dropoff'] -- RHS: ['not shared', 'low count']
# Support: 0.2821789321789322
# Confidence: 0.8081598916300268
# Lift: 0.9850966422233796
# ----------------------------------------
# LHS: ['night pickup'] -- RHS: ['not shared', 'low count']
# Support: 0.27534872534872534
# Confidence: 0.8073858160362943
# Lift: 0.9841530922203289
# ----------------------------------------
# LHS: ['noon dropoff'] -- RHS: ['noon pickup', 'low count']
# Support: 0.26713163379830046
# Confidence: 0.9525334095619238
# Lift: 3.3098602311727334
# ----------------------------------------
# LHS: ['noon dropoff'] -- RHS: ['not shared', 'low count']
# Support: 0.23207471540804875
# Confidence: 0.8275280497391553
# Lift: 1.008705222303828
# ----------------------------------------
# LHS: ['noon pickup'] -- RHS: ['not shared', 'low count']
# Support: 0.23745791245791245
# Confidence: 0.8251180411437803
# Lift: 1.005767571723019
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'short trip', 'low count']
# Support: 0.4215127465127465
# Confidence: 0.4215127465127465
# Lift: 1.0
# ----------------------------------------
# LHS: ['night dropoff'] -- RHS: ['not shared', 'night pickup']
# Support: 0.2658449575116242
# Confidence: 0.7613794211849522
# Lift: 2.7651459806856766
# ----------------------------------------
# LHS: ['noon dropoff'] -- RHS: ['not shared', 'noon pickup']
# Support: 0.22112393779060446
# Confidence: 0.7884799542628457
# Lift: 3.320504025750658
# ----------------------------------------
# LHS: ['night dropoff'] -- RHS: ['not shared', 'night pickup', 'low count']
# Support: 0.2658449575116242
# Confidence: 0.7613794211849522
# Lift: 2.7651459806856766
# ----------------------------------------
# LHS: ['noon dropoff'] -- RHS: ['not shared', 'noon pickup', 'low count']
# Support: 0.22112393779060446
# Confidence: 0.7884799542628457
# Lift: 3.320504025750658
# ----------------------------------------

# %%
for i in range(len(rules_2020)):
    LHS=list(rules_2020[i][2][0][0])
    RHS=list(rules_2020[i][2][0][1])
    support=rules_2020[i][1]
    confidence=rules_2020[i][2][0][2]
    lift=rules_2020[i][2][0][3]
    print("LHS:",LHS,"--","RHS:",RHS)
    print("Support:",support)
    print("Confidence:",confidence)
    print("Lift:",lift)
    print(10*"----")
# Out:
# LHS: [] -- RHS: ['low count']
# Support: 0.6625428392481404
# Confidence: 0.6625428392481404
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['medium-short trip']
# Support: 0.3467392910676209
# Confidence: 0.3467392910676209
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['night dropoff']
# Support: 0.32773168380236595
# Confidence: 0.32773168380236595
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['night pickup']
# Support: 0.31878030414986525
# Confidence: 0.31878030414986525
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['noon dropoff']
# Support: 0.3093152053820874
# Confidence: 0.3093152053820874
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['noon pickup']
# Support: 0.3159935538806905
# Confidence: 0.3159935538806905
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared']
# Support: 0.9520763400679798
# Confidence: 0.9520763400679798
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['short trip']
# Support: 0.5486449778678546
# Confidence: 0.5486449778678546
# Lift: 1.0
# ----------------------------------------
# LHS: ['low count'] -- RHS: ['medium-short trip']
# Support: 0.2327921689502537
# Confidence: 0.3513616858563114
# Lift: 1.0133310383558147
# ----------------------------------------
# LHS: ['low count'] -- RHS: ['night dropoff']
# Support: 0.22320743696384965
# Confidence: 0.33689510132982114
# Lift: 1.0279601209780531
# ----------------------------------------
# LHS: ['low count'] -- RHS: ['night pickup']
# Support: 0.21755652669580086
# Confidence: 0.32836597697242637
# Lift: 1.0300698402560489
# ----------------------------------------
# LHS: ['low count'] -- RHS: ['noon pickup']
# Support: 0.20390426527610644
# Confidence: 0.30776012236053873
# Lift: 0.9739443054485204
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'low count']
# Support: 0.6161392249174883
# Confidence: 0.6161392249174883
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['short trip', 'low count']
# Support: 0.35689404015453796
# Confidence: 0.35689404015453796
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'medium-short trip']
# Support: 0.3269646237535274
# Confidence: 0.3269646237535274
# Lift: 1.0
# ----------------------------------------
# LHS: ['morning dropoff'] -- RHS: ['morning pickup']
# Support: 0.23849937720353834
# Confidence: 0.9795936063820563
# Lift: 3.910476474435952
# ----------------------------------------
# LHS: ['morning dropoff'] -- RHS: ['not shared']
# Support: 0.23337626054707566
# Confidence: 0.9585513194785675
# Lift: 1.0068009036020424
# ----------------------------------------
# LHS: ['morning pickup'] -- RHS: ['not shared']
# Support: 0.24015313051984152
# Confidence: 0.9586762929460348
# Lift: 1.0069321677267853
# ----------------------------------------
# LHS: [] -- RHS: ['night pickup', 'night dropoff']
# Support: 0.3090477899522171
# Confidence: 0.3090477899522171
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'night dropoff']
# Support: 0.30929409363762395
# Confidence: 0.30929409363762395
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'night pickup']
# Support: 0.3007438371299287
# Confidence: 0.3007438371299287
# Lift: 1.0
# ----------------------------------------
# LHS: ['noon dropoff'] -- RHS: ['noon pickup']
# Support: 0.29730966003054166
# Confidence: 0.9611866951813259
# Lift: 3.0417920978990622
# ----------------------------------------
# LHS: ['noon dropoff'] -- RHS: ['not shared']
# Support: 0.2973941070083954
# Confidence: 0.9614597078764161
# Lift: 1.0098556884711223
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'noon pickup']
# Support: 0.3033616934433959
# Confidence: 0.3033616934433959
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'short trip']
# Support: 0.5289829065242327
# Confidence: 0.5289829065242327
# Lift: 1.0
# ----------------------------------------
# LHS: ['low count'] -- RHS: ['not shared', 'medium-short trip']
# Support: 0.21365789121821802
# Confidence: 0.32248162467604197
# Lift: 0.9862890393889682
# ----------------------------------------
# LHS: ['low count'] -- RHS: ['night pickup', 'night dropoff']
# Support: 0.21066002350440885
# Confidence: 0.3179568339210605
# Lift: 1.0288273990576695
# ----------------------------------------
# LHS: ['low count'] -- RHS: ['not shared', 'night dropoff']
# Support: 0.20522023068099451
# Confidence: 0.30974635679993207
# Lift: 1.0014622431259164
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'short trip', 'low count']
# Support: 0.337886432889283
# Confidence: 0.337886432889283
# Lift: 1.0
# ----------------------------------------
# LHS: ['morning dropoff'] -- RHS: ['morning pickup', 'not shared']
# Support: 0.22867537877988192
# Confidence: 0.9392432869902015
# Lift: 3.911018294690108
# ----------------------------------------
# LHS: ['night dropoff'] -- RHS: ['not shared', 'night pickup']
# Support: 0.29184875546266387
# Confidence: 0.89051126237358
# Lift: 2.9610291298799165
# ----------------------------------------
# LHS: ['noon dropoff'] -- RHS: ['not shared', 'noon pickup']
# Support: 0.28591635526843584
# Confidence: 0.9243527324020567
# Lift: 3.0470318183878784
# ----------------------------------------

# %%
for i in range(len(rules_2021)):
    LHS=list(rules_2021[i][2][0][0])
    RHS=list(rules_2021[i][2][0][1])
    support=rules_2021[i][1]
    confidence=rules_2021[i][2][0][2]
    lift=rules_2021[i][2][0][3]
    print("LHS:",LHS,"--","RHS:",RHS)
    print("Support:",support)
    print("Confidence:",confidence)
    print("Lift:",lift)
    print(10*"----")
# Out:
# LHS: [] -- RHS: ['low count']
# Support: 0.33137499068722925
# Confidence: 0.33137499068722925
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['medium-short trip']
# Support: 0.35508796577157636
# Confidence: 0.35508796577157636
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['night dropoff']
# Support: 0.3275860233936801
# Confidence: 0.3275860233936801
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['night pickup']
# Support: 0.31843290015645453
# Confidence: 0.31843290015645453
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['noon dropoff']
# Support: 0.31827325265813083
# Confidence: 0.31827325265813083
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['noon pickup']
# Support: 0.323541620102813
# Confidence: 0.323541620102813
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared']
# Support: 0.9995317006715838
# Confidence: 0.9995317006715838
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['short trip']
# Support: 0.5276243387932777
# Confidence: 0.5276243387932777
# Lift: 1.0
# ----------------------------------------
# LHS: ['higher count'] -- RHS: ['not shared']
# Support: 0.28044743872196853
# Confidence: 0.9997723478524814
# Lift: 1.0002407599286105
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'low count']
# Support: 0.3311834136892408
# Confidence: 0.3311834136892408
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'medium-short trip']
# Support: 0.3549602477729174
# Confidence: 0.3549602477729174
# Lift: 1.0
# ----------------------------------------
# LHS: ['morning dropoff'] -- RHS: ['morning pickup']
# Support: 0.22982853858680036
# Confidence: 0.9802533024649327
# Lift: 4.030530810016965
# ----------------------------------------
# LHS: ['morning dropoff'] -- RHS: ['not shared']
# Support: 0.2343944570388582
# Confidence: 0.999727631758137
# Lift: 1.000196022883938
# ----------------------------------------
# LHS: ['morning pickup'] -- RHS: ['not shared']
# Support: 0.2431324967804421
# Confidence: 0.999693667673187
# Lift: 1.000162042886178
# ----------------------------------------
# LHS: [] -- RHS: ['night pickup', 'night dropoff']
# Support: 0.3089285524229169
# Confidence: 0.3089285524229169
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'night dropoff']
# Support: 0.327351873729472
# Confidence: 0.327351873729472
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'night pickup']
# Support: 0.3182306799919112
# Confidence: 0.3182306799919112
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['noon pickup', 'noon dropoff']
# Support: 0.30489479229860467
# Confidence: 0.30489479229860467
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'noon dropoff']
# Support: 0.3181774641591366
# Confidence: 0.3181774641591366
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'noon pickup']
# Support: 0.32342454527070896
# Confidence: 0.32342454527070896
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'short trip']
# Support: 0.5274327617952893
# Confidence: 0.5274327617952893
# Lift: 1.0
# ----------------------------------------
# LHS: ['morning dropoff'] -- RHS: ['morning pickup', 'not shared']
# Support: 0.22976467958747088
# Confidence: 0.9799809342230696
# Lift: 4.0306456240937205
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'night pickup', 'night dropoff']
# Support: 0.30872633225837354
# Confidence: 0.30872633225837354
# Lift: 1.0
# ----------------------------------------
# LHS: [] -- RHS: ['not shared', 'noon pickup', 'noon dropoff']
# Support: 0.30480964696616536
# Confidence: 0.30480964696616536
# Lift: 1.0
# ----------------------------------------

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, asc, desc, to_timestamp, unix_timestamp, from_unixtime
from pyspark.ml.fpm import FPGrowth

spark = SparkSession\
    .builder\
    .master('local[*]')\
    .config("spark.driver.memory", "4g")\
    .appName('process_tripdata')\
    .getOrCreate()
# Out:
# 21/11/30 22:51:08 WARN Utils: Your hostname, LAPTOP-VD4O2HIL resolves to a loopback address: 127.0.1.1; using 172.30.167.142 instead (on interface eth0)
# 21/11/30 22:51:08 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 21/11/30 22:51:09 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
spark_2020_df = spark.createDataFrame([(i, sample_2020_transactions[i]) for i in range(len(sample_2020_transactions))], ['id', 'trip_info'])
spark_2021_df = spark.createDataFrame([(i, sample_2021_transactions[i]) for i in range(len(sample_2021_transactions))], ['id', 'trip_info'])

# %%
fp_growth_2020 = FPGrowth(itemsCol="trip_info", minSupport=0.3, minConfidence=0.5)
fp_growth_2021 = FPGrowth(itemsCol="trip_info", minSupport=0.3, minConfidence=0.5)

# %%
fp_growth_2020_model = fp_growth_2020.fit(spark_2020_df)
fp_growth_2021_model = fp_growth_2021.fit(spark_2021_df)

# %%
fp_growth_2020_model.associationRules.show(fp_growth_2020_model.associationRules.count())
# Out:
# +--------------------+---------------+------------------+------------------+-------------------+
# |          antecedent|     consequent|        confidence|              lift|            support|
# +--------------------+---------------+------------------+------------------+-------------------+
# |        [short trip]|    [low count]|0.6505008786219104|0.9818246309327027|0.35689404015453796|
# |        [short trip]|   [not shared]|0.9641624873337352|1.0126945148798598| 0.5289829065242327|
# |[low count, not s...|   [short trip]|0.5483929917536606|0.9995407118913705|  0.337886432889283|
# |         [low count]|   [not shared]|0.9299613374686664|0.9767718179009318| 0.6161392249174883|
# |         [low count]|   [short trip]|0.5386731529081871|0.9818246309327024|0.35689404015453796|
# | [medium-short trip]|   [not shared]|0.9429696379282351|0.9904349034247668| 0.3269646237535274|
# |[short trip, not ...|    [low count]|0.6387473559579082|0.9640846117705604|  0.337886432889283|
# |[short trip, low ...|   [not shared]|0.9467415951888002|0.9943967257092023|  0.337886432889283|
# |       [noon pickup]|   [not shared]|0.9600249426541656|1.0083487029891094| 0.3033616934433959|
# |     [night dropoff]|   [not shared]|0.9437418135749716|0.9912459472604758|0.30929409363762395|
# |     [night dropoff]| [night pickup]| 0.942990272916622|2.9581196223255457| 0.3090477899522171|
# |        [not shared]|    [low count]|0.6471531735296508|0.9767718179009317| 0.6161392249174883|
# |        [not shared]|   [short trip]|0.5556097597031584|1.0126945148798598| 0.5289829065242327|
# |      [night pickup]|[night dropoff]|0.9694695247135698|2.9581196223255453| 0.3090477899522171|
# |      [night pickup]|   [not shared]|0.9434203845559505|0.9909083388088278| 0.3007438371299287|
# +--------------------+---------------+------------------+------------------+-------------------+

# %%
fp_growth_2021_model.associationRules.show(fp_growth_2021_model.associationRules.count())
# Out:
# +--------------------+---------------+------------------+------------------+-------------------+
# |          antecedent|     consequent|        confidence|              lift|            support|
# +--------------------+---------------+------------------+------------------+-------------------+
# |        [short trip]|   [not shared]|0.9996369064428935|1.0001052550621845| 0.5274327617952893|
# |[night pickup, no...|[night dropoff]|0.9701337792642141|  2.96146266929815|0.30872633225837354|
# |[noon dropoff, no...|  [noon pickup]|0.9579862853319954| 2.960936787754146|0.30480964696616536|
# |         [low count]|   [not shared]| 0.999421872490766|0.9998901203626218| 0.3311834136892408|
# |[noon dropoff, no...|   [not shared]|0.9997207386462806|1.0001891265425298|0.30480964696616536|
# | [medium-short trip]|   [not shared]|0.9996403201150975| 1.000108670333758| 0.3549602477729174|
# |[night pickup, ni...|   [not shared]| 0.999345414456005| 0.999813626505839|0.30872633225837354|
# |      [noon dropoff]|  [noon pickup]|0.9579654895666132| 2.960872512359297|0.30489479229860467|
# |      [noon dropoff]|   [not shared]| 0.999699036918138|1.0001674146467208| 0.3181774641591366|
# |       [noon pickup]|   [not shared]|0.9996381459916445|1.0001064951916874|0.32342454527070896|
# |       [noon pickup]| [noon dropoff]|0.9423665252146453|2.9608725123592974|0.30489479229860467|
# |     [night dropoff]|   [not shared]|0.9992852269404464|0.9997534107913018|  0.327351873729472|
# |     [night dropoff]| [night pickup]|0.9430455830273888|2.9615205670144182| 0.3089285524229169|
# |        [not shared]|   [short trip]|0.5276798739258676|1.0001052550621847| 0.5274327617952893|
# |      [night pickup]|[night dropoff]|0.9701527457468498| 2.961520567014418| 0.3089285524229169|
# |      [night pickup]|   [not shared]| 0.999364952037167|0.9998331732407238| 0.3182306799919112|
# |[noon pickup, not...| [noon dropoff]|0.9424443859418191|2.9611171472022306|0.30480964696616536|
# |[night dropoff, n...| [night pickup]| 0.943102383197321|2.9616989410765964|0.30872633225837354|
# +--------------------+---------------+------------------+------------------+-------------------+

# %%
# import pyspark to process large files and create a new spark session
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, asc, desc, to_timestamp, unix_timestamp, from_unixtime

spark = SparkSession\
    .builder\
    .master('local[*]')\
    .config("spark.driver.memory", "4g")\
    .appName('process_tripdata')\
    .getOrCreate()
# Out:
# 21/11/10 13:08:10 WARN Utils: Your hostname, LAPTOP-VD4O2HIL resolves to a loopback address: 127.0.1.1; using 172.17.55.88 instead (on interface eth0)
# 21/11/10 13:08:10 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 21/11/10 13:08:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
# read 2019 samples
jan_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201901_sample.csv', header=True)
feb_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201902_sample.csv', header=True)
mar_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201903_sample.csv', header=True)
apr_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201904_sample.csv', header=True)
may_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201905_sample.csv', header=True)
jun_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201906_sample.csv', header=True)
jul_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201907_sample.csv', header=True)
aug_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201908_sample.csv', header=True)
sep_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201909_sample.csv', header=True)
oct_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201910_sample.csv', header=True)
nov_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201911_sample.csv', header=True)
dec_sample = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/201912_sample.csv', header=True)

# %%
# cast string cols to appropriate data type
jan_sample = jan_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

feb_sample = feb_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

mar_sample = mar_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

apr_sample = apr_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

may_sample = may_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

jun_sample = jun_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

jul_sample = jul_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

aug_sample = aug_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

sep_sample = sep_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

oct_sample = oct_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

nov_sample = nov_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

dec_sample = dec_sample\
    .withColumn('pickup_datetime', to_timestamp('pickup_datetime'))\
    .withColumn('dropoff_datetime', to_timestamp('dropoff_datetime'))\
    .withColumn('PULocationID', col('PULocationID').cast('int'))\
    .withColumn('DOLocationID', col('DOLocationID').cast('int'))\
    .withColumn('SR_Flag', col('SR_Flag').cast('int'))\
    .na.fill(value=0, subset=["SR_Flag"])

# %%
# Out:
# +--------------------+-------------------+-------------------+------------+------------+-------+
# |dispatching_base_num|    pickup_datetime|   dropoff_datetime|PULocationID|DOLocationID|SR_Flag|
# +--------------------+-------------------+-------------------+------------+------------+-------+
# |              B01066|2019-01-01 00:21:11|2019-01-01 00:31:44|          70|          70|      0|
# |              B02395|2019-01-01 00:04:58|2019-01-01 00:22:50|         255|          37|      0|
# |              B02395|2019-01-01 00:30:45|2019-01-01 00:44:05|          36|          37|      0|
# |              B02395|2019-01-01 00:30:01|2019-01-01 00:47:13|          76|          72|      0|
# |              B02395|2019-01-01 00:50:43|2019-01-01 01:06:40|         148|          87|      0|
# |              B02395|2019-01-01 00:47:38|2019-01-01 00:57:49|           3|          51|      3|
# |              B02395|2019-01-01 00:50:01|2019-01-01 01:15:26|          61|         145|      0|
# |              B02510|2019-01-01 00:35:29|2019-01-01 00:58:33|          45|         198|      0|
# |              B02510|2019-01-01 00:46:00|2019-01-01 01:04:08|          71|         165|      0|
# |              B02510|2019-01-01 00:43:11|2019-01-01 00:49:45|          35|          72|      0|
# |              B02510|2019-01-01 00:11:19|2019-01-01 00:23:04|         140|         170|      2|
# |              B02510|2019-01-01 00:42:08|2019-01-01 00:46:48|         260|          83|      0|
# |              B02510|2019-01-01 00:39:09|2019-01-01 00:48:01|         161|         163|      0|
# |              B02510|2019-01-01 00:25:24|2019-01-01 00:34:05|         228|         195|      0|
# |              B02510|2019-01-01 00:58:32|2019-01-01 01:21:49|         143|         145|      0|
# |              B02510|2019-01-01 00:07:14|2019-01-01 00:29:49|         262|         186|      0|
# |              B02510|2019-01-01 00:25:47|2019-01-01 00:56:37|         234|         166|      0|
# |              B02510|2019-01-01 00:08:06|2019-01-01 00:16:38|         116|          42|      0|
# |              B02510|2019-01-01 00:41:13|2019-01-01 00:47:59|         228|         181|      0|
# |              B02510|2019-01-01 00:33:00|2019-01-01 00:45:55|          42|         243|      0|
# +--------------------+-------------------+-------------------+------------+------------+-------+
# only showing top 20 rows

# %%
# read covid data cases by day
covid_data = spark\
    .read\
    .csv('/home/felipe/repos/tcc/nyc_data/csv/coronavirus-data/trends/cases-by-day.csv', header=True)

# %%
covid_data = covid_data\
    .drop("BX_CASE_COUNT")\
    .drop("BX_PROBABLE_CASE_COUNT")\
    .drop("BX_CASE_COUNT_7DAY_AVG")\
    .drop("BX_ALL_CASE_COUNT_7DAY_AVG")\
    .drop("BK_CASE_COUNT")\
    .drop("BK_PROBABLE_CASE_COUNT")\
    .drop("BK_CASE_COUNT_7DAY_AVG")\
    .drop("BK_ALL_CASE_COUNT_7DAY_AVG")\
    .drop("MN_CASE_COUNT")\
    .drop("MN_PROBABLE_CASE_COUNT")\
    .drop("MN_CASE_COUNT_7DAY_AVG")\
    .drop("MN_ALL_CASE_COUNT_7DAY_AVG")\
    .drop("QN_CASE_COUNT")\
    .drop("QN_PROBABLE_CASE_COUNT")\
    .drop("QN_CASE_COUNT_7DAY_AVG")\
    .drop("QN_ALL_CASE_COUNT_7DAY_AVG")\
    .drop("SI_CASE_COUNT")\
    .drop("SI_PROBABLE_CASE_COUNT")\
    .drop("SI_CASE_COUNT_7DAY_AVG")\
    .drop("SI_ALL_CASE_COUNT_7DAY_AVG")

# %%
covid_data = covid_data\
    .withColumn('date_of_interest', from_unixtime(unix_timestamp('date_of_interest', 'MM/dd/yyy')))\
    .withColumn('CASE_COUNT', col('CASE_COUNT').cast('int'))\
    .withColumn('PROBABLE_CASE_COUNT', col('PROBABLE_CASE_COUNT').cast('int'))\
    .withColumn('CASE_COUNT_7DAY_AVG', col('CASE_COUNT_7DAY_AVG').cast('int'))\
    .withColumn('ALL_CASE_COUNT_7DAY_AVG', col('ALL_CASE_COUNT_7DAY_AVG').cast('int'))\
    .withColumn('INCOMPLETE', col('INCOMPLETE').cast('int'))

# %%
covid_data.printSchema()
# Out:
# root
#  |-- date_of_interest: string (nullable = true)
#  |-- CASE_COUNT: integer (nullable = true)
#  |-- PROBABLE_CASE_COUNT: integer (nullable = true)
#  |-- CASE_COUNT_7DAY_AVG: integer (nullable = true)
#  |-- ALL_CASE_COUNT_7DAY_AVG: integer (nullable = true)
#  |-- INCOMPLETE: integer (nullable = true)

# %%
covid_data.show()
# Out:
# +-------------------+----------+-------------------+-------------------+-----------------------+----------+
# |   date_of_interest|CASE_COUNT|PROBABLE_CASE_COUNT|CASE_COUNT_7DAY_AVG|ALL_CASE_COUNT_7DAY_AVG|INCOMPLETE|
# +-------------------+----------+-------------------+-------------------+-----------------------+----------+
# |2020-02-29 00:00:00|         1|                  0|                  0|                      0|         0|
# |2020-03-01 00:00:00|         0|                  0|                  0|                      0|         0|
# |2020-03-02 00:00:00|         0|                  0|                  0|                      0|         0|
# |2020-03-03 00:00:00|         1|                  0|                  0|                      0|         0|
# |2020-03-04 00:00:00|         5|                  0|                  0|                      0|         0|
# |2020-03-05 00:00:00|         3|                  0|                  0|                      0|         0|
# |2020-03-06 00:00:00|         8|                  0|                  3|                      3|         0|
# |2020-03-07 00:00:00|         7|                  0|                  3|                      3|         0|
# |2020-03-08 00:00:00|        21|                  0|                  6|                      6|         0|
# |2020-03-09 00:00:00|        57|                  0|                 15|                     15|         0|
# |2020-03-10 00:00:00|        69|                  0|                 24|                     24|         0|
# |2020-03-11 00:00:00|       155|                  0|                 46|                     46|         0|
# |2020-03-12 00:00:00|       355|                  0|                 96|                     96|         0|
# |2020-03-13 00:00:00|       619|                  0|                183|                    183|         0|
# |2020-03-14 00:00:00|       642|                  1|                274|                    274|         0|
# |2020-03-15 00:00:00|      1035|                  0|                419|                    419|         0|
# |2020-03-16 00:00:00|      2121|                  1|                714|                    714|         0|
# |2020-03-17 00:00:00|      2452|                  3|               1054|                   1055|         0|
# |2020-03-18 00:00:00|      2971|                  5|               1456|                   1458|         0|
# |2020-03-19 00:00:00|      3706|                  4|               1935|                   1937|         0|
# +-------------------+----------+-------------------+-------------------+-----------------------+----------+
# only showing top 20 rows
